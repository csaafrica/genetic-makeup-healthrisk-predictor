# %% [markdown]
# # BMI Prediction Model

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
bio_data = pd.read_csv(r'C:\Users\ryanj\Desktop\CSA2025\data\anthropometric_trait_gwas.csv')

# %%
bio_data.columns
# Out:
# Index(['age', 'sex', 'cohort', 'systolic_BP', 'diastolic_BP',
#        'LDL_cholesterol', 'HDL_cholesterol', 'height', 'weight', 'BMI',
#        ...
#        'SNP_991', 'SNP_992', 'SNP_993', 'SNP_994', 'SNP_995', 'SNP_996',
#        'SNP_997', 'SNP_998', 'SNP_999', 'SNP_1000'],
#       dtype='object', length=1013)

# %%
features_to_scale = ['LDL_cholesterol', 'HDL_cholesterol', 'systolic_BP', 'diastolic_BP', 'BMI', 'age', 'weight', 'height', 'waist_circumference', 'hip_circumference']
scaler = StandardScaler()
bio_data[features_to_scale] = scaler.fit_transform(bio_data[features_to_scale])

# %%
df = bio_data['sex']
df
# Out:
# 0        Male
# 1        Male
# 2        Male
# 3      Female
# 4        Male
#         ...
# 995    Female
# 996      Male
# 997    Female
# 998      Male
# 999      Male
# Name: sex, Length: 1000, dtype: object

# %%
encoder = OneHotEncoder()
one_hot_encoded = encoder.fit_transform(df.to_frame())
one_hot_df = pd.DataFrame(one_hot_encoded.toarray(), columns=encoder.get_feature_names_out([df.name]))
bio_data = pd.concat([bio_data, one_hot_df], axis=1)

bio_data
# Out:
#           age     sex   cohort  systolic_BP  diastolic_BP  LDL_cholesterol  \
# 0    0.812959    Male  Ugandan    -0.606279      0.444187         1.172468
# 1    1.680578    Male     Zulu     1.095283     -0.377477        -0.548804
# 2    0.145560    Male     Zulu     0.101649      0.185789         0.933073
# 3   -0.788799  Female  Ugandan     0.274759     -0.446832        -0.261840
# 4    1.079919    Male     Zulu    -0.848938      1.276010        -1.287763
# ..        ...     ...      ...          ...           ...              ...
# 995  1.079919  Female  Ugandan     0.440924     -0.451885        -0.586172
# 996  1.346879    Male     Zulu     1.335696      0.672409        -1.016762
# 997  1.213399  Female     Zulu     0.015416     -1.209443         0.359200
# 998 -0.588580    Male  Ugandan     0.144177     -0.905162        -0.950735
# 999  0.746219    Male  Ugandan     1.133733      0.716522         1.308724
#
#      HDL_cholesterol    height    weight       BMI  ...  SNP_993  SNP_994  \
# 0          -1.039078  0.679301  0.090362 -0.336726  ...        1        1
# 1           0.161857  0.833478  0.636477  0.162759  ...        2        0
# 2          -0.471807  1.218919 -0.229065 -1.004657  ...        1        1
# 3          -0.254707 -1.016640 -1.517073 -1.312590  ...        2        1
# 4           2.616544  1.450184  1.136224  0.248922  ...        1        1
# ..               ...       ...       ...       ...  ...      ...      ...
# 995        -2.240235 -0.939551 -0.970957 -0.574905  ...        1        2
# 996         2.036893  0.756390  0.791038  0.390309  ...        2        1
# 997         0.122714 -1.016640 -0.177544  0.631511  ...        0        1
# 998         0.708337  0.987654  0.445852 -0.151409  ...        2        2
# 999         0.521216  0.833478 -0.064199 -0.606174  ...        0        0
#
#      SNP_995  SNP_996  SNP_997  SNP_998  SNP_999  SNP_1000  sex_Female  \
# 0          2        2        0        2        1         1         0.0
# 1          0        0        1        0        2         0         0.0
# 2          1        2        1        1        0         1         0.0
# 3          1        0        1        0        0         2         1.0
# 4          1        2        1        1        1         0         0.0
# ..       ...      ...      ...      ...      ...       ...         ...
# 995        1        1        1        0        0         1         1.0
# 996        2        2        0        2        0         0         0.0
# 997        1        0        0        2        0         0         1.0
# 998        2        2        0        2        2         0         0.0
# 999        2        1        2        2        1         1         0.0
#
#      sex_Male
# 0         1.0
# 1         1.0
# 2         1.0
# 3         0.0
# 4         1.0
# ..        ...
# 995       0.0
# 996       1.0
# 997       0.0
# 998       1.0
# 999       1.0
#
# [1000 rows x 1015 columns]

# %%
bio_data2 = bio_data.drop(columns=['sex', 'cohort'])
bio_data2
# Out:
#           age  systolic_BP  diastolic_BP  LDL_cholesterol  HDL_cholesterol  \
# 0    0.812959    -0.606279      0.444187         1.172468        -1.039078
# 1    1.680578     1.095283     -0.377477        -0.548804         0.161857
# 2    0.145560     0.101649      0.185789         0.933073        -0.471807
# 3   -0.788799     0.274759     -0.446832        -0.261840        -0.254707
# 4    1.079919    -0.848938      1.276010        -1.287763         2.616544
# ..        ...          ...           ...              ...              ...
# 995  1.079919     0.440924     -0.451885        -0.586172        -2.240235
# 996  1.346879     1.335696      0.672409        -1.016762         2.036893
# 997  1.213399     0.015416     -1.209443         0.359200         0.122714
# 998 -0.588580     0.144177     -0.905162        -0.950735         0.708337
# 999  0.746219     1.133733      0.716522         1.308724         0.521216
#
#        height    weight       BMI  waist_circumference  hip_circumference  \
# 0    0.679301  0.090362 -0.336726            -0.507418          -1.610935
# 1    0.833478  0.636477  0.162759             1.193366           0.222913
# 2    1.218919 -0.229065 -1.004657             0.466989          -0.302641
# 3   -1.016640 -1.517073 -1.312590            -0.294820          -0.906469
# 4    1.450184  1.136224  0.248922             1.397105           0.491281
# ..        ...       ...       ...                  ...                ...
# 995 -0.939551 -0.970957 -0.574905            -1.783006          -1.152473
# 996  0.756390  0.791038  0.390309             0.378407           0.077547
# 997 -1.016640 -0.177544  0.631511             1.281948           1.229293
# 998  0.987654  0.445852 -0.151409            -0.959189          -0.123729
# 999  0.833478 -0.064199 -0.606174            -1.127496           0.591919
#
#      ...  SNP_993  SNP_994  SNP_995  SNP_996  SNP_997  SNP_998  SNP_999  \
# 0    ...        1        1        2        2        0        2        1
# 1    ...        2        0        0        0        1        0        2
# 2    ...        1        1        1        2        1        1        0
# 3    ...        2        1        1        0        1        0        0
# 4    ...        1        1        1        2        1        1        1
# ..   ...      ...      ...      ...      ...      ...      ...      ...
# 995  ...        1        2        1        1        1        0        0
# 996  ...        2        1        2        2        0        2        0
# 997  ...        0        1        1        0        0        2        0
# 998  ...        2        2        2        2        0        2        2
# 999  ...        0        0        2        1        2        2        1
#
#      SNP_1000  sex_Female  sex_Male
# 0           1         0.0       1.0
# 1           0         0.0       1.0
# 2           1         0.0       1.0
# 3           2         1.0       0.0
# 4           0         0.0       1.0
# ..        ...         ...       ...
# 995         1         1.0       0.0
# 996         0         0.0       1.0
# 997         0         1.0       0.0
# 998         0         0.0       1.0
# 999         1         0.0       1.0
#
# [1000 rows x 1013 columns]

# %% [markdown]
# # set the Target, Y and Data, X

# %%
Y = bio_data2['BMI']
X = bio_data2.drop(columns=['BMI'], axis=1)

# %%
Y
# Out:
# 0     -0.336726
# 1      0.162759
# 2     -1.004657
# 3     -1.312590
# 4      0.248922
#          ...
# 995   -0.574905
# 996    0.390309
# 997    0.631511
# 998   -0.151409
# 999   -0.606174
# Name: BMI, Length: 1000, dtype: float64

# %%
X
# Out:
#           age  systolic_BP  diastolic_BP  LDL_cholesterol  HDL_cholesterol  \
# 0    0.812959    -0.606279      0.444187         1.172468        -1.039078
# 1    1.680578     1.095283     -0.377477        -0.548804         0.161857
# 2    0.145560     0.101649      0.185789         0.933073        -0.471807
# 3   -0.788799     0.274759     -0.446832        -0.261840        -0.254707
# 4    1.079919    -0.848938      1.276010        -1.287763         2.616544
# ..        ...          ...           ...              ...              ...
# 995  1.079919     0.440924     -0.451885        -0.586172        -2.240235
# 996  1.346879     1.335696      0.672409        -1.016762         2.036893
# 997  1.213399     0.015416     -1.209443         0.359200         0.122714
# 998 -0.588580     0.144177     -0.905162        -0.950735         0.708337
# 999  0.746219     1.133733      0.716522         1.308724         0.521216
#
#        height    weight  waist_circumference  hip_circumference       WHR  \
# 0    0.679301  0.090362            -0.507418          -1.610935  1.013605
# 1    0.833478  0.636477             1.193366           0.222913  1.038241
# 2    1.218919 -0.229065             0.466989          -0.302641  1.005005
# 3   -1.016640 -1.517073            -0.294820          -0.906469  0.971429
# 4    1.450184  1.136224             1.397105           0.491281  1.036449
# ..        ...       ...                  ...                ...       ...
# 995 -0.939551 -0.970957            -1.783006          -1.152473  0.812568
# 996  0.756390  0.791038             0.378407           0.077547  0.962246
# 997 -1.016640 -0.177544             1.281948           1.229293  0.964789
# 998  0.987654  0.445852            -0.959189          -0.123729  0.830542
# 999  0.833478 -0.064199            -1.127496           0.591919  0.763670
#
#      ...  SNP_993  SNP_994  SNP_995  SNP_996  SNP_997  SNP_998  SNP_999  \
# 0    ...        1        1        2        2        0        2        1
# 1    ...        2        0        0        0        1        0        2
# 2    ...        1        1        1        2        1        1        0
# 3    ...        2        1        1        0        1        0        0
# 4    ...        1        1        1        2        1        1        1
# ..   ...      ...      ...      ...      ...      ...      ...      ...
# 995  ...        1        2        1        1        1        0        0
# 996  ...        2        1        2        2        0        2        0
# 997  ...        0        1        1        0        0        2        0
# 998  ...        2        2        2        2        0        2        2
# 999  ...        0        0        2        1        2        2        1
#
#      SNP_1000  sex_Female  sex_Male
# 0           1         0.0       1.0
# 1           0         0.0       1.0
# 2           1         0.0       1.0
# 3           2         1.0       0.0
# 4           0         0.0       1.0
# ..        ...         ...       ...
# 995         1         1.0       0.0
# 996         0         0.0       1.0
# 997         0         1.0       0.0
# 998         0         0.0       1.0
# 999         1         0.0       1.0
#
# [1000 rows x 1012 columns]

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Perform 80/20 Data split

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train.shape, Y_train.shape
# Out:
# ((800, 1012), (800,))

# %%
X_test.shape, Y_test.shape
# Out:
# ((200, 1012), (200,))

# %% [markdown]
# ## Import model training modules

# %%
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
model = linear_model.LinearRegression()

# %% [markdown]
# Train the model

# %%
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predict the target Y using X_test

# %%
Y_pred = model.predict(X_test)

# %% [markdown]
# ## Prediction results

# %%
print("Coefficients: ", model.coef_)
print("Intercept: ", model.intercept_)
print("Mean squared error: %.2f" % mean_squared_error(Y_test, Y_pred))
print("Coefficient of determination: %.2f" % r2_score(Y_test, Y_pred))
# Out:
# Coefficients:  [-0.01011375 -0.00152676  0.00478662 ...  0.03959257  0.09125941
#  -0.09125941]
# Intercept:  -1.101791440999116
# Mean squared error: 0.42
# Coefficient of determination: 0.49

# %%
bio_data2
# Out:
#           age  systolic_BP  diastolic_BP  LDL_cholesterol  HDL_cholesterol  \
# 0    0.812959    -0.606279      0.444187         1.172468        -1.039078
# 1    1.680578     1.095283     -0.377477        -0.548804         0.161857
# 2    0.145560     0.101649      0.185789         0.933073        -0.471807
# 3   -0.788799     0.274759     -0.446832        -0.261840        -0.254707
# 4    1.079919    -0.848938      1.276010        -1.287763         2.616544
# ..        ...          ...           ...              ...              ...
# 995  1.079919     0.440924     -0.451885        -0.586172        -2.240235
# 996  1.346879     1.335696      0.672409        -1.016762         2.036893
# 997  1.213399     0.015416     -1.209443         0.359200         0.122714
# 998 -0.588580     0.144177     -0.905162        -0.950735         0.708337
# 999  0.746219     1.133733      0.716522         1.308724         0.521216
#
#        height    weight       BMI  waist_circumference  hip_circumference  \
# 0    0.679301  0.090362 -0.336726            -0.507418          -1.610935
# 1    0.833478  0.636477  0.162759             1.193366           0.222913
# 2    1.218919 -0.229065 -1.004657             0.466989          -0.302641
# 3   -1.016640 -1.517073 -1.312590            -0.294820          -0.906469
# 4    1.450184  1.136224  0.248922             1.397105           0.491281
# ..        ...       ...       ...                  ...                ...
# 995 -0.939551 -0.970957 -0.574905            -1.783006          -1.152473
# 996  0.756390  0.791038  0.390309             0.378407           0.077547
# 997 -1.016640 -0.177544  0.631511             1.281948           1.229293
# 998  0.987654  0.445852 -0.151409            -0.959189          -0.123729
# 999  0.833478 -0.064199 -0.606174            -1.127496           0.591919
#
#      ...  SNP_993  SNP_994  SNP_995  SNP_996  SNP_997  SNP_998  SNP_999  \
# 0    ...        1        1        2        2        0        2        1
# 1    ...        2        0        0        0        1        0        2
# 2    ...        1        1        1        2        1        1        0
# 3    ...        2        1        1        0        1        0        0
# 4    ...        1        1        1        2        1        1        1
# ..   ...      ...      ...      ...      ...      ...      ...      ...
# 995  ...        1        2        1        1        1        0        0
# 996  ...        2        1        2        2        0        2        0
# 997  ...        0        1        1        0        0        2        0
# 998  ...        2        2        2        2        0        2        2
# 999  ...        0        0        2        1        2        2        1
#
#      SNP_1000  sex_Female  sex_Male
# 0           1         0.0       1.0
# 1           0         0.0       1.0
# 2           1         0.0       1.0
# 3           2         1.0       0.0
# 4           0         0.0       1.0
# ..        ...         ...       ...
# 995         1         1.0       0.0
# 996         0         0.0       1.0
# 997         0         1.0       0.0
# 998         0         0.0       1.0
# 999         1         0.0       1.0
#
# [1000 rows x 1013 columns]

# %%
r2_score(Y_test, Y_pred)
# Out:
# 0.4872642873692422

# %% [markdown]
# Scatter Plots showing model accuracy

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Get the index of the test set to align with the original DataFrame
test_idx = X_test.index

# Use the original 'sex' column from bio_data for hue
sex_test = bio_data.loc[test_idx, 'sex']

sns.scatterplot(x=Y_test, y=Y_pred, color='blue', label='Predicted vs Actual', alpha=0.5, ax=ax)
# Out:
# <Axes: xlabel='BMI'>

# %%
Y_pred
# Out:
# array([ 6.30275481e-02, -2.10167364e-01,  1.41275924e+00, -1.00834993e+00,
#         1.30388781e-01, -1.25358692e+00,  1.22254785e+00,  1.52426010e+00,
#        -8.27958026e-02,  1.48961549e+00, -8.64558711e-01, -1.52893423e-01,
#        -2.30716937e-01,  8.07907853e-01,  9.53676628e-01,  3.42203728e-01,
#        -1.20961514e+00,  8.44089182e-01,  2.78260042e-01,  2.88446108e-01,
#         6.99586648e-01, -4.22388461e-01, -4.39847639e-03, -1.76464063e-01,
#        -2.82850070e-01, -7.46404213e-02, -3.34375364e-01, -9.47275536e-01,
#         2.96315611e-02, -9.33145721e-01, -4.52363978e-01,  6.01083484e-01,
#        -9.61228530e-02, -1.22780845e+00, -1.05890754e+00,  1.13885049e+00,
#        -3.71678181e-03,  1.71386949e-01, -1.22888361e+00,  6.35408904e-01,
#         1.83643348e+00,  1.07302027e+00, -1.15254749e+00,  1.01248437e-01,
#        -1.27511535e+00, -5.40867102e-01,  6.39492710e-01,  3.39727632e-01,
#         8.92844820e-01,  3.28555305e-01, -7.33557798e-01,  8.07580707e-01,
#         1.74578048e+00,  1.86950669e+00, -4.40921355e-01,  1.37415052e+00,
#         1.36025217e+00,  7.14018158e-02,  8.82024432e-03, -1.01324826e+00,
#         1.27443744e+00, -7.57825338e-01, -3.82132618e-01, -9.25336154e-01,
#        -4.21914189e-01,  9.96618687e-01, -1.80785791e+00, -1.27243094e-01,
#        -6.83447136e-01,  5.90452461e-01, -6.29082572e-01,  1.16870477e+00,
#         7.24493144e-01, -1.28992912e+00,  3.86156358e-04, -7.42424274e-01,
#        -3.16951689e-01, -8.35319052e-01,  7.50496898e-02, -6.48188300e-01,
#         1.19686050e-02,  2.89244680e-01, -4.59144621e-01, -1.21292211e+00,
#         7.65120682e-01, -5.31748983e-02,  1.46792795e+00,  4.67478085e-01,
#        -2.46315502e-01,  7.00768197e-01, -5.31399958e-01, -8.77421627e-01,
#         4.92018044e-03, -7.59475171e-01, -2.05882400e+00,  2.15510558e-01,
#         1.30069049e-01, -1.22811053e+00, -6.60185059e-01,  1.17743226e+00,
#        -6.42639105e-01,  8.15183460e-01, -1.21516928e+00, -1.73756849e-03,
#         1.11110433e-01,  9.22786149e-01,  9.29605682e-01, -1.22995881e+00,
#         8.99819627e-01, -6.58034327e-01, -2.34165701e+00,  9.02988720e-01,
#         1.77624462e+00,  5.45200845e-01, -1.40560192e+00, -9.58553547e-01,
#        -6.63150761e-01,  7.86291877e-02,  1.01131580e+00, -5.55658108e-02,
#        -1.72373588e-01,  8.56615150e-01,  3.46972455e-01,  6.87564544e-01,
#         1.15599738e+00,  1.71223455e-01,  9.06897837e-01,  1.54798851e+00,
#        -3.68874370e-03,  5.42932994e-01, -7.84463341e-01,  2.23617715e-01,
#        -2.55606221e-01, -7.00863090e-01,  8.79968505e-01,  1.24664206e+00,
#         1.15830065e+00,  2.89218942e-01,  3.15234571e-01, -4.87633082e-01,
#        -8.02001639e-02,  1.88247556e-01,  1.52177687e+00, -2.04229098e+00,
#         6.70707624e-01,  3.48757602e-01,  1.04843055e+00, -1.18737663e+00,
#        -1.10401342e-01,  1.23895954e+00, -7.09301840e-01, -8.36890402e-01,
#         1.32814423e-02,  9.43396174e-01,  3.79730127e-01, -4.31796496e-01,
#         1.01898143e+00,  8.26614320e-01,  1.87289345e-01,  4.36878087e-01,
#         3.65647888e-01, -4.62786875e-01,  2.76813137e+00,  3.85612283e-01,
#        -1.80398419e+00, -9.91619664e-02,  5.00655121e-01, -3.84145103e-01,
#        -1.38944156e-01, -1.00348740e+00,  1.80318949e+00,  3.05493834e-01,
#        -5.44035212e-01, -1.09955174e+00, -9.91057091e-01, -6.86010857e-02,
#        -1.22732346e+00, -2.14123524e+00,  7.31487292e-01,  7.25605401e-01,
#         5.27251746e-01, -3.32553326e-02, -6.59330525e-01, -8.20657393e-02,
#        -1.24819122e+00, -8.64475865e-01, -9.46498673e-01,  1.66130187e-01,
#         5.69150224e-01,  1.57185299e+00, -8.32591608e-01,  1.07550133e+00,
#        -8.67235137e-02,  1.36326159e+00,  7.88693243e-01, -3.93526949e-02,
#         5.64352770e-01, -1.23709475e+00,  5.77204199e-01,  9.92464394e-02])
